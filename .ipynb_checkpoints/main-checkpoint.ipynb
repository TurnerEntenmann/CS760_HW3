# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.lines as mlines
from sklearn import neighbors, metrics
from matplotlib import pyplot as plt

# %%
# fxn for plotting
def get_ax(figsize=(6,4)):
    fig, ax = plt.subplots(figsize=figsize)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    return ax

# %%
# D is the name of the data file
# returns a df with columns x_1, x_2, y of float values
def read_data(D):
    df = pd.read_csv("data/"+D, sep = " ", names = ["x_1", "x_2", "y"])
    return df

# %%
D2z_df = read_data("D2z.txt")

# %%
def oneNN(x_1, x_2, df):
    best_dist = None
    best_y = 1
    for i, row in df.iterrows():
        dist = np.sqrt((row[0]-x_1)**2+(row[1]-x_2)**2)
        if best_dist == None:
            best_dist = dist
            best_y = row[2]
        elif dist < best_dist:
            best_dist = dist
            best_y = row[2]
    return best_y

# %%
# make a grid, predict each point and plot to see decision boundaries
d1 = {"x_1":[], "x_2":[], "y":[]}
grid_x = np.linspace(-2, 2, 20)
for x_1 in grid_x:
    for x_2 in grid_x:
        y = oneNN(x_1, x_2, D2z_df)
        d1["x_1"].append(x_1)
        d1["x_2"].append(x_2)
        d1["y"].append(int(y))

boundary1_df = pd.DataFrame(d1)

# %%
# make axies
ax = get_ax()

# set colors (colorblind friendly via https://yoshke.org/blog/colorblind-friendly-diagrams)
colors = {0: '#000000', 1: '#E69F00'}

# make plot
boundary1_df.plot.scatter(x="x_1", y="x_2", c=boundary1_df["y"].map(colors), s=10, alpha=0.4, ax=ax)
D2z_df.plot.scatter(x="x_1", y="x_2", c=D2z_df["y"].map(colors), alpha=0.8, ax=ax)
# plot settings
fsize = 15
# legend
b_dot = mlines.Line2D([], [], color='#000000', marker='.', linestyle='None',
                          markersize=10, label='0')
o_dot = mlines.Line2D([], [], color='#E69F00', marker='.', linestyle='None',
                          markersize=10, label='1')
ax.legend(handles=[b_dot, o_dot], fontsize=fsize, bbox_to_anchor=(1, 1), frameon=False)

# axies settings
plt.xticks(size=fsize-2)
plt.yticks(size=fsize-2)
plt.xlabel("$x_1$", size=fsize)
plt.ylabel("$x_2$", size=fsize)

plt.tight_layout()
plt.savefig("Plots/D1Boundary_plot.pdf")

# %%
emails_df = pd.read_csv("data/emails.csv")

# %%
single_train_df = emails_df[:4000]
single_test_df = emails_df[4000:]

f1_test_df = emails_df[:1000]
f1_train_df = emails_df[1000:]

f2_test_df = emails_df[1000:2000]
f2_train_df = emails_df.iloc[np.r_[0:1000, 2000:5000]]

f3_test_df = emails_df[2000:3000]
f3_train_df = emails_df.iloc[np.r_[0:2000, 3000:5000]]

f4_test_df = emails_df[3000:4000]
f4_train_df = emails_df.iloc[np.r_[0:3000, 4000:5000]]

f5_test_df = emails_df[4000:]
f5_train_df = emails_df[:4000]

# %%
knn1 = neighbors.KNeighborsClassifier(n_neighbors=1)
knn1.fit(f1_train_df.drop(["Email No.", "Prediction"], axis=1), f1_train_df["Prediction"])
pred_1 = knn1.predict(f1_test_df.drop(["Email No.", "Prediction"], axis=1))
acc_1 = metrics.accuracy_score(f1_test_df["Prediction"], pred_1)
pre_1 = metrics.precision_score(f1_test_df["Prediction"], pred_1)
rec_1 = metrics.recall_score(f1_test_df["Prediction"], pred_1)
print(f"fold 1: acc: {acc_1}, pre: {pre_1}, rec: {rec_1}")
# Out:
# fold 1: acc: 0.824, pre: 0.6526610644257703, rec: 0.8175438596491228

# %%
knn2 = neighbors.KNeighborsClassifier(n_neighbors=1)
knn2.fit(f2_train_df.drop(["Email No.", "Prediction"], axis=1), f2_train_df["Prediction"])
pred_2 = knn2.predict(f2_test_df.drop(["Email No.", "Prediction"], axis=1))
acc_2 = metrics.accuracy_score(f2_test_df["Prediction"], pred_2)
pre_2 = metrics.precision_score(f2_test_df["Prediction"], pred_2)
rec_2 = metrics.recall_score(f2_test_df["Prediction"], pred_2)
print(f"fold 2: acc: {acc_2}, pre: {pre_2}, rec: {rec_2}")
# Out:
# fold 2: acc: 0.855, pre: 0.6896551724137931, rec: 0.8664259927797834

# %%
knn3 = neighbors.KNeighborsClassifier(n_neighbors=1)
knn3.fit(f3_train_df.drop(["Email No.", "Prediction"], axis=1), f3_train_df["Prediction"])
pred_3 = knn3.predict(f3_test_df.drop(["Email No.", "Prediction"], axis=1))
acc_3 = metrics.accuracy_score(f3_test_df["Prediction"], pred_3)
pre_3 = metrics.precision_score(f3_test_df["Prediction"], pred_3)
rec_3 = metrics.recall_score(f3_test_df["Prediction"], pred_3)
print(f"fold 3: acc: {acc_3}, pre: {pre_3}, rec: {rec_3}")
# Out:
# fold 3: acc: 0.861, pre: 0.7217125382262997, rec: 0.8309859154929577

# %%
knn4 = neighbors.KNeighborsClassifier(n_neighbors=1)
knn4.fit(f4_train_df.drop(["Email No.", "Prediction"], axis=1), f4_train_df["Prediction"])
pred_4 = knn4.predict(f4_test_df.drop(["Email No.", "Prediction"], axis=1))
acc_4 = metrics.accuracy_score(f4_test_df["Prediction"], pred_4)
pre_4 = metrics.precision_score(f4_test_df["Prediction"], pred_4)
rec_4 = metrics.recall_score(f4_test_df["Prediction"], pred_4)
print(f"fold 4: acc: {acc_4}, pre: {pre_4}, rec: {rec_4}")
# Out:
# fold 4: acc: 0.854, pre: 0.7215568862275449, rec: 0.8197278911564626

# %%
knn5 = neighbors.KNeighborsClassifier(n_neighbors=1)
knn5.fit(f5_train_df.drop(["Email No.", "Prediction"], axis=1), f5_train_df["Prediction"])
pred_5 = knn5.predict(f5_test_df.drop(["Email No.", "Prediction"], axis=1))
acc_5 = metrics.accuracy_score(f5_test_df["Prediction"], pred_5)
pre_5 = metrics.precision_score(f5_test_df["Prediction"], pred_5)
rec_5 = metrics.recall_score(f5_test_df["Prediction"], pred_5)
print(f"fold 4: acc: {acc_5}, pre: {pre_5}, rec: {rec_5}")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-3bb220f1bd0c> in <module>
#       1 knn5 = neighbors.KNeighborsClassifier(n_neighbors=1)
# ----> 2 knn5.fit(f5_train_df.drop(["Email No.", "Prediction"], axis=1), f5_train_df["Prediction"])
#       3 pred_5 = knn5.predict(f5_test_df.drop(["Email No.", "Prediction"], axis=1))
#       4 acc_5 = metrics.accuracy_score(f5_test_df["Prediction"], pred_5)
#       5 pre_5 = metrics.precision_score(f5_test_df["Prediction"], pred_5)
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4108                 weight  1.0     0.8
#    4109         """
# -> 4110         return super().drop(
#    4111             labels=labels,
#    4112             axis=axis,
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3945             else:
#    3946                 new_axis = axis.drop(labels, errors=errors)
# -> 3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#    3949         # Case for non-unique axis
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     219         @wraps(func)
#     220         def wrapper(*args, **kwargs):
# --> 221             return func(*args, **kwargs)
#     222
#     223         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3974         kwargs.pop("axis", None)
#    3975         kwargs.pop("labels", None)
# -> 3976         return super().reindex(**kwargs)
#    3977
#    3978     def drop(
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4511
#    4512         # perform the reindex on the axes
# -> 4513         return self._reindex_axes(
#    4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3855         columns = axes["columns"]
#    3856         if columns is not None:
# -> 3857             frame = frame._reindex_columns(
#    3858                 columns, method, copy, level, fill_value, limit, tolerance
#    3859             )
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3900             new_columns, method=method, level=level, limit=limit, tolerance=tolerance
#    3901         )
# -> 3902         return self._reindex_with_indexers(
#    3903             {1: [new_columns, indexer]},
#    3904             copy=copy,
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4569
#    4570             # TODO: speed up on homogeneous DataFrame objects
# -> 4571             new_data = new_data.reindex_indexer(
#    4572                 index,
#    4573                 indexer,
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1255
#    1256         if axis == 0:
# -> 1257             new_blocks = self._slice_take_blocks_ax0(indexer, fill_tuple=(fill_value,))
#    1258         else:
#    1259             new_blocks = [
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple)
#    1351                 else:
#    1352                     blocks.append(
# -> 1353                         blk.take_nd(
#    1354                             blklocs[mgr_locs.indexer],
#    1355                             axis=0,
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1310             allow_fill = True
#    1311
# -> 1312         new_values = algos.take_nd(
#    1313             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1314         )
#
# c:\users\tente\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1714             out = np.empty(out_shape, dtype=dtype, order="F")
#    1715         else:
# -> 1716             out = np.empty(out_shape, dtype=dtype)
#    1717
#    1718     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 91.6 MiB for an array with shape (3000, 4000) and data type int64
